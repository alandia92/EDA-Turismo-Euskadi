# %%
import pickle

with open('variables.pkl', 'rb') as f:
    df_13, df_21, df_20, df_4, df_5, df_6, df_7, df_11, df_16, df_12, df_17 = pickle.load(f)

# %%
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import normalize
import locale
locale.setlocale(locale.LC_TIME, 'es_ES.utf8')
# Out:
# 'es_ES.utf8'

# %%
# Ruta de carpeta para guardar los df en excel para posterior visualización
ruta_carpeta='./DF_DV'
#df.to_excel(ruta_carpeta + '/nombre_del_archivo.xlsx')

# %% [markdown]
# Numero de turistas por provincia año 2016-2022

# %%
df_20.head()
# Out:
#          Total     Tasa de variación anual     Andalucía  \
# 2022  71659281                      129.82      10009890
# 2021  31180802                       64.69       4248340
# 2020  18933103                      -77.33       2700613
# 2019  83509153                        0.85      12023153
# 2018  82808413                        1.15      11681256
#
#          Tasa de variación anual     Aragón     Tasa de variación anual  \
# 2022                      135.62     385175                       78.42
# 2021                       57.31     215884                       25.45
# 2020                      -77.54     172084                      -68.41
# 2019                        2.93     544761                       -0.14
# 2018                        1.42     545530                       -2.99
#
#          Asturias, Principado de     Tasa de variación anual  \
# 2022                      277267                       71.72
# 2021                      161462                       75.08
# 2020                       92222                      -70.99
# 2019                      317860                        6.18
# 2018                      299357                        1.78
#
#          Balears, Illes     Tasa de variación anual  ...  \
# 2022           13203885                      108.77  ...
# 2021            6324711                      267.48  ...
# 2020            1721123                      -87.42  ...
# 2019           13679781                       -1.24  ...
# 2018           13851598                        0.43  ...
#
#          Navarra, Comunidad Foral de     Tasa de variación anual  \
# 2022                          273406                      121.18
# 2021                          123614                      -15.52
# 2020                          146325                      -64.75
# 2019                          415054                       28.21
# 2018                          323730                       -2.88
#
#          País Vasco     Tasa de variación anual     Rioja, La  \
# 2022        1545013                      131.05        105910
# 2021         668683                       26.82         47913
# 2020         527286                      -67.28         45355
# 2019        1611280                        3.79        139497
# 2018        1552389                        2.48        142926
#
#          Tasa de variación anual     Ceuta     Tasa de variación anual  \
# 2022                      121.05     35937                         179
# 2021                        5.64      3942                          ..
# 2020                      -67.49
# 2019                        -2.4
# 2018                       15.09
#
#          Melilla     Tasa de variación anual
# 2022       25224                          ..
# 2021        8918                          ..
# 2020
# 2019
# 2018
#
# [5 rows x 40 columns]

# %%
df_20 = df_20.sort_index(ascending=True)

# %%
print(df_20.columns)
# Out:
# Index(['    Total', '    Tasa de variación anual', '    Andalucía',
#        '    Tasa de variación anual', '    Aragón',
#        '    Tasa de variación anual', '    Asturias, Principado de',
#        '    Tasa de variación anual', '    Balears, Illes',
#        '    Tasa de variación anual', '    Canarias',
#        '    Tasa de variación anual', '    Cantabria',
#        '    Tasa de variación anual', '    Castilla y León',
#        '    Tasa de variación anual', '    Castilla - La Mancha',
#        '    Tasa de variación anual', '    Cataluña',
#        '    Tasa de variación anual', '    Comunitat Valenciana',
#        '    Tasa de variación anual', '    Extremadura',
#        '    Tasa de variación anual', '    Galicia',
#        '    Tasa de variación anual', '    Madrid, Comunidad de',
#        '    Tasa de variación anual', '    Murcia, Región de',
#        '    Tasa de variación anual', '    Navarra, Comunidad Foral de',
#        '    Tasa de variación anual', '    País Vasco',
#        '    Tasa de variación anual', '    Rioja, La',
#        '    Tasa de variación anual', '    Ceuta',
#        '    Tasa de variación anual', '    Melilla',
#        '    Tasa de variación anual'],
#       dtype='object', name=' ')

# %%
df_20.to_csv(ruta_carpeta + 'datos.csv', index=True)

# %%
df_madrid = df_20['    Madrid, Comunidad de']
df_madrid.index = pd.to_datetime(df_madrid.index)
df_madrid.index = df_madrid.index.strftime('%Y')

# %%
df_vasco = df_20['    País Vasco']
df_vasco.index = pd.to_datetime(df_vasco.index, format='%Y')

# %%
df_vasco.index
# Out:
# Index(['2016', '2017', '2018', '2019', '2020', '2021', '2022'], dtype='object')

# %% [markdown]
# Precio alquiler Euskadi

# %%
df_4.head()
# Out:
#             Precio m2 Variación mensual Variación trimestral Variación anual
# Fecha
# 2023-02-01       12.8           + 0,1 %              + 1,4 %         + 5,4 %
# 2023-01-01       12.8           + 0,6 %              + 1,8 %         + 5,1 %
# 2022-12-01       12.8           + 0,8 %              + 1,2 %         + 4,5 %
# 2022-11-01       12.7           + 0,5 %              + 1,4 %         + 2,1 %
# 2022-10-01       12.6             0,0 %              + 1,6 %         + 1,4 %

# %%
media_anual_4 = df_4[['Precio m2']].resample('A').mean()
media_anual_4.index = media_anual_4.index.shift(1, freq='D')
media_anual_4['Precio m2 alquiler Euskadi'] = media_anual_4['Precio m2'] 
del media_anual_4['Precio m2']
media_anual_4.head()
# Out:
#             Precio m2 alquiler Euskadi
# Fecha
# 2012-01-01                   11.030000
# 2013-01-01                   10.791667
# 2014-01-01                    9.950000
# 2015-01-01                    9.775000
# 2016-01-01                    9.775000

# %% [markdown]
# Precio compra Euskadi

# %%
df_5.head()
# Out:
#             Precio m2 Variación mensual Variación trimestral Variación anual
# Fecha
# 2023-02-01       2803           + 0,6 %              + 0,5 %         + 4,1 %
# 2023-01-01       2787           + 0,1 %              + 0,1 %         + 3,0 %
# 2022-12-01       2783           - 0,2 %              + 1,2 %         + 2,8 %
# 2022-11-01       2788           + 0,1 %              + 2,0 %         + 3,6 %
# 2022-10-01       2785           + 1,3 %              + 2,0 %         + 3,8 %

# %%
media_anual_5 = df_5[['Precio m2']].resample('A').mean()
media_anual_5.index = media_anual_5.index.shift(1, freq='D')
media_anual_5['Precio m2 compra Euskadi'] = media_anual_5['Precio m2'] 
del media_anual_5['Precio m2']
media_anual_5.head()
# Out:
#             Precio m2 compra Euskadi
# Fecha
# 2012-01-01               3192.600000
# 2013-01-01               3023.416667
# 2014-01-01               2815.000000
# 2015-01-01               2655.166667
# 2016-01-01               2548.500000

# %% [markdown]
# Precio compra Madrid

# %%
df_6.head()
# Out:
#             Precio m2 Variación mensual Variación trimestral Variación anual
# Fecha
# 2023-02-01       3995           + 1,7 %              + 0,5 %         + 6,1 %
# 2023-01-01       3929           - 0,3 %              - 1,1 %         + 4,9 %
# 2022-12-01       3939           - 0,9 %              - 1,3 %         + 6,5 %
# 2022-11-01       3973             0,0 %                0,0 %         + 8,2 %
# 2022-10-01       3974           - 0,5 %              + 1,9 %         + 7,9 %

# %%
media_anual_6 = df_6[['Precio m2']].resample('A').mean()
media_anual_6.index = media_anual_6.index.shift(1, freq='D')
media_anual_6['Precio m2 compra Madrid'] = media_anual_6['Precio m2'] 
del media_anual_6['Precio m2']
media_anual_6.head()
# Out:
#             Precio m2 compra Madrid
# Fecha
# 2012-01-01              3174.700000
# 2013-01-01              2925.166667
# 2014-01-01              2713.250000
# 2015-01-01              2665.000000
# 2016-01-01              2726.833333

# %% [markdown]
# Precio alquiler Madrid

# %%
df_7.head()
# Out:
#             Precio m2 Variación mensual Variación trimestral Variación anual
# Fecha
# 2023-02-01       16.6           + 0,5 %              + 2,5 %        + 10,9 %
# 2023-01-01       16.5           + 2,0 %              + 1,3 %        + 12,3 %
# 2022-12-01       16.2             0,0 %              - 0,8 %        + 11,2 %
# 2022-11-01       16.2           - 0,7 %              + 0,6 %        + 10,7 %
# 2022-10-01       16.3           - 0,1 %              + 2,6 %        + 10,4 %

# %%
media_anual_7 = df_7[['Precio m2']].resample('A').mean()
media_anual_7.index = media_anual_7.index.shift(1, freq='D')
media_anual_7['Precio m2 alquiler Madrid'] = media_anual_7['Precio m2'] 
del media_anual_7['Precio m2']
media_anual_7
# Out:
#             Precio m2 alquiler Madrid
# Fecha
# 2012-01-01                  12.330000
# 2013-01-01                  11.883333
# 2014-01-01                  11.258333
# 2015-01-01                  11.308333
# 2016-01-01                  11.833333
# 2017-01-01                  12.783333
# 2018-01-01                  14.016667
# 2019-01-01                  15.308333
# 2020-01-01                  16.025000
# 2021-01-01                  16.075000
# 2022-01-01                  14.608333
# 2023-01-01                  15.666667
# 2024-01-01                  16.550000

# %%
df = pd.concat([media_anual_4, media_anual_5, media_anual_6, media_anual_7], axis=1)
df = df.drop(df.index[-1])
df
# Out:
#             Precio m2 alquiler Euskadi  Precio m2 compra Euskadi  \
# Fecha
# 2012-01-01                   11.030000               3192.600000
# 2013-01-01                   10.791667               3023.416667
# 2014-01-01                    9.950000               2815.000000
# 2015-01-01                    9.775000               2655.166667
# 2016-01-01                    9.775000               2548.500000
# 2017-01-01                    9.983333               2522.250000
# 2018-01-01                   10.550000               2497.750000
# 2019-01-01                   11.133333               2507.500000
# 2020-01-01                   11.500000               2557.250000
# 2021-01-01                   12.133333               2620.250000
# 2022-01-01                   12.208333               2680.250000
# 2023-01-01                   12.458333               2731.666667
#
#             Precio m2 compra Madrid  Precio m2 alquiler Madrid
# Fecha
# 2012-01-01              3174.700000                  12.330000
# 2013-01-01              2925.166667                  11.883333
# 2014-01-01              2713.250000                  11.258333
# 2015-01-01              2665.000000                  11.308333
# 2016-01-01              2726.833333                  11.833333
# 2017-01-01              2804.666667                  12.783333
# 2018-01-01              2925.500000                  14.016667
# 2019-01-01              3466.083333                  15.308333
# 2020-01-01              3768.583333                  16.025000
# 2021-01-01              3707.083333                  16.075000
# 2022-01-01              3713.583333                  14.608333
# 2023-01-01              3878.500000                  15.666667

# %%
df = df.drop(df.index[:4])
# Out:
#             Precio m2 alquiler Euskadi  Precio m2 compra Euskadi  \
# Fecha
# 2016-01-01                    9.775000               2548.500000
# 2017-01-01                    9.983333               2522.250000
# 2018-01-01                   10.550000               2497.750000
# 2019-01-01                   11.133333               2507.500000
# 2020-01-01                   11.500000               2557.250000
# 2021-01-01                   12.133333               2620.250000
# 2022-01-01                   12.208333               2680.250000
# 2023-01-01                   12.458333               2731.666667
#
#             Precio m2 compra Madrid  Precio m2 alquiler Madrid
# Fecha
# 2016-01-01              2726.833333                  11.833333
# 2017-01-01              2804.666667                  12.783333
# 2018-01-01              2925.500000                  14.016667
# 2019-01-01              3466.083333                  15.308333
# 2020-01-01              3768.583333                  16.025000
# 2021-01-01              3707.083333                  16.075000
# 2022-01-01              3713.583333                  14.608333
# 2023-01-01              3878.500000                  15.666667

# %%
df_norm = df.apply(lambda x: (x - x.min()) / (x.max() - x.min()))
df_norm
# Out:
#             Precio m2 alquiler Euskadi  Precio m2 compra Euskadi  \
# Fecha
# 2012-01-01                    0.467702                  1.000000
# 2013-01-01                    0.378882                  0.756518
# 2014-01-01                    0.065217                  0.456573
# 2015-01-01                    0.000000                  0.226548
# 2016-01-01                    0.000000                  0.073037
# 2017-01-01                    0.077640                  0.035259
# 2018-01-01                    0.288820                  0.000000
# 2019-01-01                    0.506211                  0.014032
# 2020-01-01                    0.642857                  0.085630
# 2021-01-01                    0.878882                  0.176297
# 2022-01-01                    0.906832                  0.262647
# 2023-01-01                    1.000000                  0.336643
#
#             Precio m2 compra Madrid  Precio m2 alquiler Madrid
# Fecha
# 2012-01-01                 0.420025                   0.222491
# 2013-01-01                 0.214394                   0.129758
# 2014-01-01                 0.039761                   0.000000
# 2015-01-01                 0.000000                   0.010381
# 2016-01-01                 0.050955                   0.119377
# 2017-01-01                 0.115094                   0.316609
# 2018-01-01                 0.214668                   0.572664
# 2019-01-01                 0.660143                   0.840830
# 2020-01-01                 0.909422                   0.989619
# 2021-01-01                 0.858742                   1.000000
# 2022-01-01                 0.864098                   0.695502
# 2023-01-01                 1.000000                   0.915225

# %%
#df.to_excel(ruta_carpeta + '/Precio_vivienda.xlsx', index= True)

# %%
df.to_csv(ruta_carpeta + '/Precio_vivienda.csv', index= True)
df_norm.to_csv(ruta_carpeta + '/Norm_Precio_vivienda.csv', index= True)

# %% [markdown]
# Pernoctaciones y grados de ocupación en establecimientos hoteleros, categoría, día de la semana y periodo

# %%
df_11.head()
# Out:
# Año          Total  -Laborables -Fin de semana  Pernoctacion por dia laboral  \
# 2011-01-01  120035        75258          44777                       15051.6
# 2011-02-01  140090        80002          60088                       16000.4
# 2011-03-01  177734       107670          70064                       21534.0
# 2011-04-01  218319       122848          95471                       24569.6
# 2011-05-01  207706       133278          74428                       26655.6
#
# Año        Pernoctacion por dia Finde
# 2011-01-01                    22388.5
# 2011-02-01                    30044.0
# 2011-03-01                    35032.0
# 2011-04-01                    47735.5
# 2011-05-01                    37214.0

# %%
df_11 = df_11.drop(df_11.index[111])

# %%
#Fines de semana 2 dias y laborables 5
df_11['-Laborables'] = pd.to_numeric(df_11['-Laborables'])
df_11['Pernoctacion por dia laboral'] = df_11['-Laborables']/ 5
df_11['Pernoctacion por dia Finde'] = df_11['-Fin de semana'] / 2
df_11
# Out:
# Año          Total  -Laborables -Fin de semana  Pernoctacion por dia laboral  \
# 2011-01-01  120035        75258          44777                       15051.6
# 2011-02-01  140090        80002          60088                       16000.4
# 2011-03-01  177734       107670          70064                       21534.0
# 2011-04-01  218319       122848          95471                       24569.6
# 2011-05-01  207706       133278          74428                       26655.6
# ...            ...          ...            ...                           ...
# 2022-09-01  330304       212065         118239                       42413.0
# 2022-10-01  322320       200471         121849                       40094.2
# 2022-11-01  247036       150254          96782                       30050.8
# 2022-12-01  239673       144684          94989                       28936.8
# 2023-01-01  191439       122187          69252                       24437.4
#
# Año        Pernoctacion por dia Finde
# 2011-01-01                    22388.5
# 2011-02-01                    30044.0
# 2011-03-01                    35032.0
# 2011-04-01                    47735.5
# 2011-05-01                    37214.0
# ...                               ...
# 2022-09-01                    59119.5
# 2022-10-01                    60924.5
# 2022-11-01                    48391.0
# 2022-12-01                    47494.5
# 2023-01-01                    34626.0
#
# [141 rows x 5 columns]

# %%
df_por_año = df_11.groupby(pd.Grouper(freq='Y')).agg({'Total': 'sum', '-Laborables': 'sum', '-Fin de semana': 'sum', 'Pernoctacion por dia laboral': 'sum', 'Pernoctacion por dia Finde': 'sum'})

# %%
df_por_año
# Out:
# Año           Total  -Laborables -Fin de semana  Pernoctacion por dia laboral  \
# 2011-12-31  2420997      1497620         923377                      299524.0
# 2012-12-31  2420107      1521828         898279                      304365.6
# 2013-12-31  2368080      1494286         873794                      298857.2
# 2014-12-31  2424832      1519990         904842                      303998.0
# 2015-12-31  2637385      1662097         975288                      332419.4
# 2016-12-31  2837225      1800813        1036412                      360162.6
# 2017-12-31  2940493      1898586        1041907                      379717.2
# 2018-12-31  3071130      1985559        1085571                      397111.8
# 2019-12-31  3184904      2049623        1135281                      409924.6
# 2020-12-31  1001357       624603         376754                      124920.6
# 2021-12-31  2172927      1352932         819995                      270586.4
# 2022-12-31  3340493      2112147        1228346                      422429.4
# 2023-12-31   191439       122187          69252                       24437.4
#
# Año        Pernoctacion por dia Finde
# 2011-12-31                   461688.5
# 2012-12-31                   449139.5
# 2013-12-31                   436897.0
# 2014-12-31                   452421.0
# 2015-12-31                   487644.0
# 2016-12-31                   518206.0
# 2017-12-31                   520953.5
# 2018-12-31                   542785.5
# 2019-12-31                   567640.5
# 2020-12-31                   188377.0
# 2021-12-31                   409997.5
# 2022-12-31                   614173.0
# 2023-12-31                    34626.0

# %%
#df_11.to_excel(ruta_carpeta + '/Pernoctaciones por dias.xlsx')

# %%
df_por_año.to_csv(ruta_carpeta + '/AÑOSPernoctaciones por dias.csv', index=True)

# %% [markdown]
# Entradas, pernoctaciones, estancia media y grado de ocupación por plazas en los establecimientos hoteleros, alojamientos rurales y apartamentos turísticos de la C.A. de Euskadi por variable, territorio histórico y periodo

# %%
df_16.head()
# Out:
# nan     Entradas    NaN     NaN     NaN Pernoctaciones    NaN     NaN     NaN  \
# 2016-01   148816  22388   66201   60228         273764  43604  121233  108928
# 2016-02   171511  22996   82009   66506         310728  45966  148425  116337
# 2016-03   223501  31487  103151   88863         438115  64116  196669  177330
# 2016-04   236863  30551  113251   93061         433356  55280  206875  171200
# 2016-05   279835  37329  126187  116319         542821  70860  247965  223996
#
# nan     Estancia media   NaN   NaN   NaN
# 2016-01           1.84  1.95  1.83  1.81
# 2016-02           1.81     2  1.81  1.75
# 2016-03           1.96  2.04  1.91     2
# 2016-04           1.83  1.81  1.83  1.84
# 2016-05           1.94   1.9  1.97  1.93

# %%
#df_16.to_excel(ruta_carpeta + '/Entradas pernoctaciones y estacia media por periodo.xlsx')

# %%
df_16.to_csv(ruta_carpeta + '/Entradas pernoctaciones y estacia media por periodo.csv', index=True)

# %% [markdown]
# Evolucion del paro por sectores

# %%
df_12.head()
# Out:
#             AGRICULTURA  INDUSTRIA  CONSTRUCCIÓN  SERVICIOS
# Unnamed: 1
# 2014-01-01     208174.0   512531.0      649211.0  3071282.0
# 2014-02-01     216083.0   507583.0      643061.0  3067530.0
# 2014-03-01     230937.0   502018.0      629169.0  3046322.0
# 2014-04-01     224699.0   493736.0      617966.0  2961616.0
# 2014-05-01     215807.0   479471.0      593772.0  2896348.0

# %% [markdown]
# la variabilidad se puede medir mediante la desviación estándar o la varianza de los valores de empleo en cada sector. Los sectores con una desviación estándar o una varianza más baja tendrán una evolución del empleo más estable.
# Calculamos la desviación estándar de los valores de empleo en cada sector y ordena los sectores de manera ascendente según su desviación estándar. Los sectores con una desviación estándar más baja tendrán una evolución del empleo más estable.

# %%
# Calcular la desviación estándar de los valores de empleo en cada sector
std_dev = df_12.std(axis=0)

# Ordenar los sectores de manera ascendente según su desviación estándar
std_dev_sorted = std_dev.sort_values(ascending=True)

print(std_dev_sorted)
# Out:
# AGRICULTURA      28558.750631
# INDUSTRIA        72749.133267
# CONSTRUCCIÓN    112293.242110
# SERVICIOS       286930.371478
# dtype: float64

# %%
df_desv = pd.DataFrame(std_dev_sorted, columns=['Desviacion'])
df_desv
# Out:
#                  Desviacion
# AGRICULTURA    28558.750631
# INDUSTRIA      72749.133267
# CONSTRUCCIÓN  112293.242110
# SERVICIOS     286930.371478

# %%
#df_desv.to_excel(ruta_carpeta + '/Desviacion estandar empleo por sector.xlsx')
#df_12.to_excel(ruta_carpeta + '/Evolucion del paro por secotres.xlsx')

# %%
df_desv.to_csv(ruta_carpeta + '/Desviacion estandar empleo por sector.csv', index=True)
df_12.to_csv(ruta_carpeta + '/Evolucion del paro por secotres.csv', index=True)

# %% [markdown]
# Salario medio anual por grupos de ocupación, periodo y sexo

# %%
df_13.head()
# Out:
# 0           K Trabajadores cualificados de la construcción, excepto operadores de máquinas  \
# año
# 2020-01-01                                            21265.6
# 2019-01-01                                            21070.1
# 2018-01-01                                            20928.8
# 2017-01-01                                            20303.3
# 2016-01-01                                            20191.7
#
# 0           N Conductores y operadores de maquinaria móvil  \
# año
# 2020-01-01                                         21182.1
# 2019-01-01                                         20920.0
# 2018-01-01                                         21487.5
# 2017-01-01                                         20452.2
# 2016-01-01                                         20161.1
#
# 0           B Técnicos y profesionales científicos e intelectuales de la salud y la enseñanza  \
# año
# 2020-01-01                                            37664.4
# 2019-01-01                                            35488.0
# 2018-01-01                                            33434.0
# 2017-01-01                                            34790.1
# 2016-01-01                                            34293.4
#
# 0           I Trabajadores de los servicios de protección y seguridad  \
# año
# 2020-01-01                                            31425.5
# 2019-01-01                                            29339.1
# 2018-01-01                                            29087.5
# 2017-01-01                                            28803.0
# 2016-01-01                                            28589.6
#
# 0           A Directores y gerentes  \
# año
# 2020-01-01                  61698.2
# 2019-01-01                  60780.8
# 2018-01-01                  58850.2
# 2017-01-01                  55478.0
# 2016-01-01                  54142.7
#
# 0           E Empleados de oficina que no atienden al público  \
# año
# 2020-01-01                                            26465.1
# 2019-01-01                                            25634.1
# 2018-01-01                                            27420.3
# 2017-01-01                                            25169.4
# 2016-01-01                                            24711.9
#
# 0           P Peones de la agricultura, pesca, construcción, industrias manufactureras y transportes  \
# año
# 2020-01-01                                            19279.7
# 2019-01-01                                            18920.6
# 2018-01-01                                            19076.6
# 2017-01-01                                            17518.8
# 2016-01-01                                            16754.3
#
# 0           D Técnicos; profesionales de apoyo  \
# año
# 2020-01-01                             32611.2
# 2019-01-01                             31816.3
# 2018-01-01                             31979.9
# 2017-01-01                             31891.6
# 2016-01-01                             31206.2
#
# 0           C Otros técnicos y profesionales científicos e intelectuales  \
# año
# 2020-01-01                                            41735.7
# 2019-01-01                                            40333.7
# 2018-01-01                                            41408.1
# 2017-01-01                                            39229.3
# 2016-01-01                                            40077.0
#
# 0           G Trabajadores de los servicios de restauración y comercio  \
# año
# 2020-01-01                                            18248.1
# 2019-01-01                                            18154.8
# 2018-01-01                                            17962.5
# 2017-01-01                                            16825.9
# 2016-01-01                                            16260.7
#
# 0           F Empleados de oficina que atienden al público  \
# año
# 2020-01-01                                         22442.0
# 2019-01-01                                         22437.5
# 2018-01-01                                         22149.7
# 2017-01-01                                         22049.9
# 2016-01-01                                         21272.7
#
# 0           H Trabajadores de los servicios de salud y el cuidado de personas  \
# año
# 2020-01-01                                            21281.8
# 2019-01-01                                            21005.6
# 2018-01-01                                            20198.0
# 2017-01-01                                            18343.6
# 2016-01-01                                            18877.8
#
# 0           M Operadores de instalaciones y maquinaria fijas, y montadores  \
# año
# 2020-01-01                                            27884.5
# 2019-01-01                                            27672.3
# 2018-01-01                                            27490.5
# 2017-01-01                                            25930.9
# 2016-01-01                                            25396.0
#
# 0           L Trabajadores cualificados de las industrias manufactureras, excepto operadores de instalaciones y máquinas  \
# año
# 2020-01-01                                            24104.1
# 2019-01-01                                            24405.8
# 2018-01-01                                            24564.8
# 2017-01-01                                            24122.8
# 2016-01-01                                            23476.7
#
# 0           O Trabajadores no cualificados en servicios (excepto transportes)  \
# año
# 2020-01-01                                            17159.2
# 2019-01-01                                            17346.8
# 2018-01-01                                            16479.0
# 2017-01-01                                            16268.2
# 2016-01-01                                            16028.1
#
# 0           J Trabajadores cualificados en el sector agrícola, ganadero, forestal y pesquero
# año
# 2020-01-01                                            22334.7
# 2019-01-01                                            22112.5
# 2018-01-01                                            19899.2
# 2017-01-01                                            19743.0
# 2016-01-01                                            18996.6

# %%
# Media entre los salarios medios de los hombre y de mujeres
df_13_mean = df_13.groupby(level=0).mean()
df_13_mean.head()
# Out:
# 0           K Trabajadores cualificados de la construcción, excepto operadores de máquinas  \
# año
# 2009-01-01                                           17972.45
# 2010-01-01                                           18710.45
# 2011-01-01                                           18921.45
# 2012-01-01                                           19124.65
# 2013-01-01                                           19004.30
#
# 0           N Conductores y operadores de maquinaria móvil  \
# año
# 2009-01-01                                        17992.15
# 2010-01-01                                        18246.45
# 2011-01-01                                        18690.60
# 2012-01-01                                        18925.05
# 2013-01-01                                        18455.45
#
# 0           B Técnicos y profesionales científicos e intelectuales de la salud y la enseñanza  \
# año
# 2009-01-01                                           30962.05
# 2010-01-01                                           32008.70
# 2011-01-01                                           30944.75
# 2012-01-01                                           30481.95
# 2013-01-01                                           30793.55
#
# 0           I Trabajadores de los servicios de protección y seguridad  \
# año
# 2009-01-01                                           24575.40
# 2010-01-01                                           24478.90
# 2011-01-01                                           24882.70
# 2012-01-01                                           24108.40
# 2013-01-01                                           23761.85
#
# 0           A Directores y gerentes  \
# año
# 2009-01-01                 55205.90
# 2010-01-01                 54452.60
# 2011-01-01                 52565.25
# 2012-01-01                 51648.05
# 2013-01-01                 50061.70
#
# 0           E Empleados de oficina que no atienden al público  \
# año
# 2009-01-01                                           21832.30
# 2010-01-01                                           21975.50
# 2011-01-01                                           22233.25
# 2012-01-01                                           21789.00
# 2013-01-01                                           21547.75
#
# 0           P Peones de la agricultura, pesca, construcción, industrias manufactureras y transportes  \
# año
# 2009-01-01                                           14405.95
# 2010-01-01                                           15110.70
# 2011-01-01                                           15167.00
# 2012-01-01                                           15199.95
# 2013-01-01                                           15054.15
#
# 0           D Técnicos; profesionales de apoyo  \
# año
# 2009-01-01                            28250.00
# 2010-01-01                            27458.90
# 2011-01-01                            27669.35
# 2012-01-01                            27851.15
# 2013-01-01                            27993.75
#
# 0           C Otros técnicos y profesionales científicos e intelectuales  \
# año
# 2009-01-01                                           35456.65
# 2010-01-01                                           34936.80
# 2011-01-01                                           33905.75
# 2012-01-01                                           34544.05
# 2013-01-01                                           35434.55
#
# 0           G Trabajadores de los servicios de restauración y comercio  \
# año
# 2009-01-01                                           15159.20
# 2010-01-01                                           15266.10
# 2011-01-01                                           14996.00
# 2012-01-01                                           14906.10
# 2013-01-01                                           15079.25
#
# 0           F Empleados de oficina que atienden al público  \
# año
# 2009-01-01                                        18387.45
# 2010-01-01                                        18793.95
# 2011-01-01                                        18923.95
# 2012-01-01                                        18752.45
# 2013-01-01                                        18845.05
#
# 0           H Trabajadores de los servicios de salud y el cuidado de personas  \
# año
# 2009-01-01                                           16567.15
# 2010-01-01                                           17015.70
# 2011-01-01                                           17029.30
# 2012-01-01                                           16314.00
# 2013-01-01                                           16395.05
#
# 0           M Operadores de instalaciones y maquinaria fijas, y montadores  \
# año
# 2009-01-01                                           18864.60
# 2010-01-01                                           19756.80
# 2011-01-01                                           20108.85
# 2012-01-01                                           20163.40
# 2013-01-01                                           20828.20
#
# 0           L Trabajadores cualificados de las industrias manufactureras, excepto operadores de instalaciones y máquinas  \
# año
# 2009-01-01                                           18344.25
# 2010-01-01                                           19588.20
# 2011-01-01                                           19561.20
# 2012-01-01                                           19265.85
# 2013-01-01                                           19179.10
#
# 0           O Trabajadores no cualificados en servicios (excepto transportes)  \
# año
# 2009-01-01                                           14683.10
# 2010-01-01                                           13784.65
# 2011-01-01                                           14011.00
# 2012-01-01                                           14019.65
# 2013-01-01                                           13744.25
#
# 0           J Trabajadores cualificados en el sector agrícola, ganadero, forestal y pesquero
# año
# 2009-01-01                                           19607.00
# 2010-01-01                                           17947.80
# 2011-01-01                                           17284.95
# 2012-01-01                                           17672.00
# 2013-01-01                                           18220.70

# %%
#df_13_mean.to_excel(ruta_carpeta + '/Salario medio por trabajo.xlsx')

# %%
df_13_mean.to_csv(ruta_carpeta + '/Salario medio por trabajo.csv', index=True)

# %% [markdown]
# Concentracion de CO2 en la atmosfera

# %%
df_21.head()
# Out:
#                CO2
# fecha
# 1991-11-01  354.95
# 1991-12-01  356.42
# 1992-01-01  356.73
# 1992-02-01  356.89
# 1992-03-01  357.68

# %%
df_21['Var %'] = df_21['CO2'].pct_change() * 100

# Marcar los períodos de subida y bajada
df_21['Subida'] = df_21['Var %'] > 0
df_21['Bajada'] = df_21['Var %'] < 0

# %%
df_21.head()
# Out:
#                CO2     Var %  Subida  Bajada
# fecha
# 1991-11-01  354.95       NaN   False   False
# 1991-12-01  356.42  0.414143    True   False
# 1992-01-01  356.73  0.086976    True   False
# 1992-02-01  356.89  0.044852    True   False
# 1992-03-01  357.68  0.221357    True   False

# %%
df_21.to_csv(ruta_carpeta + '/concentracion de CO2.csv', index=True)
