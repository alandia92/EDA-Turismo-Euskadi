# %%
import pandas as pd

# %%
fuente_2 = 'https://opendata.euskadi.eus/catalogo/-/estancia-media-y-grados-de-ocupacion-en-alojamientos-rurales-de-la-c-a-de-euskadi-por-territorio-historico-mes-y-ano/'
df_2 = pd.read_excel('./data/xls0000916_c.xlsx')
df_2.columns = df_2.iloc[3]
df_2 = df_2.drop(range(21))

df_2 = df_2.transpose().reset_index()
df_2 = df_2.drop([21,34,35,36], axis=1)
df_2.columns = df_2.iloc[0]
#df_2.columns = df_2.columns.astype(int)
df_2 = df_2.drop(df_2.index[0])
#df_2 = df_2.rename(columns=lambda x: int(x) if isinstance(x, float) else x)
estancia_opcupacion = ['Estancia media', 'Grado de ocupacion por plaza', 'Grado de acupacion por habitaciones','Estancia media', 'Grado de ocupacion por plaza', 'Grado de acupacion por habitaciones','Estancia media', 'Grado de ocupacion por plaza', 'Grado de acupacion por habitaciones', 'Estancia media', 'Grado de ocupacion por plaza', 'Grado de acupacion por habitaciones']
df_2.insert(1,'Estancia/Ocupacion', estancia_opcupacion)

df_2.head()
# Out:
# 0              NaN                   Estancia/Ocupacion 2011.0 2012.0 2013.0  \
# 1  C.A. de Euskadi                       Estancia media   2.72   2.64   2.61
# 2              NaN         Grado de ocupacion por plaza  22.26  21.72  20.02
# 3              NaN  Grado de acupacion por habitaciones  24.25  23.42  21.91
# 4      Araba/Álava                       Estancia media   2.52   2.46   2.32
# 5              NaN         Grado de ocupacion por plaza  16.82  16.01  14.19
#
# 0 2014.0 2015.0 2016.0 2017.0 2018.0 2019.0 2020.0 2021.0 2022.0
# 1    2.6    2.6   2.61   2.57   2.61   2.58   3.01   2.81   2.57
# 2  23.31  25.11  27.43  27.33  29.51  28.59  18.42  23.07  27.31
# 3  24.84  26.54  29.23  28.82   32.4   32.1  22.61  26.43  31.25
# 4    2.2   2.34   2.28   2.16   2.26   2.26   2.73   2.42   2.24
# 5   16.1  18.99  21.56  21.08  20.42  20.87  11.54  16.11  17.99

# %%
fuente_3 = 'https://opendata.euskadi.eus/catalogo/-/entradas-de-viajeros-pernoctaciones-y-grados-de-ocupacion-en-alojamientos-rurales-de-la-c-a-de-euskadi-por-origen-zona-geografica-y-dia-de-la-semana/'
df_3 = pd.read_excel('./data/xls0000466_c.xlsx')
df_3.columns = df_3.iloc[3]
df_3 = df_3.drop(range(4))
df_3 = df_3.reset_index(drop=True)
df_3.head()
# Out:
# 3                          NaN    Entradas        NaN                NaN  \
# 0                          NaN         NaN        NaN                NaN
# 1                          NaN  Laborables          %  Fin de semana (4)
# 2              C.A. DE EUSKADI        1922        100               1780
# 3      Residentes en el estado        1734  90.218522               1675
# 4  Residentes en el extranjero         188   9.781478                105
#
# 3        NaN Pernoctaciones        NaN                NaN        NaN  \
# 0        NaN            NaN        NaN                NaN        NaN
# 1          %     Laborables          %  Fin de semana (4)          %
# 2        100           5787        100               4112        100
# 3  94.101124           5139  88.802488               3845  93.506809
# 4   5.898876            648  11.197512                267   6.493191
#
# 3 Grados de ocupación                NaN               NaN                NaN
# ...

# %%
fuente_8 = 'https://www.eustat.eus/elementos/ele0019400/precio-medio-por-metro-cuadrado-construido-de-las-compraventas-de-vivienda-libre-de-la-ca-de-euskadi-por-trimestre-de-inscripcion-en-el-registro-segun-territorio-historico-y-tipo-de-vivienda-/tbl0019433_c.html'
df_8 = pd.read_excel('./data/xls0019433_c.xlsx')
df_8.head()
# Out:
#   Unnamed: 0    Total  Viviendas nuevas  Viviendas usadas
# 0       2022      NaN               NaN               NaN
# 1         IV  2932.16           3318.25           2859.48
# 2        III  2891.23           3204.35           2849.07
# 3         II  2787.09           2901.48           2772.13
# 4          I  2890.09           3138.30           2844.67

# %%
fuente_1 = "https://www.euskadi.eus/web01-s2tumerk/es/contenidos/estadistica/tur_estatis_sstur_ant/es_def/index.shtml"
df_2013 = pd.read_excel('./data/2013 Estatistika Taulak @.xlsx')
df_2014 = pd.read_excel('./data/2014 Estatistika Taulak @.xlsx')
df_2015 = pd.read_excel('./data/2015 Estatistika Taulak @.xlsx')
df_2016 = pd.read_excel('./data/2016 Estatistika Taulak @.xlsx')
df_2017 = pd.read_excel('./data/2017 Estatistika Taulak @.xlsx')
df_2018 = pd.read_excel('./data/2018-Estatistika-Taulak-4TC-.xlsx')
df_2019 = pd.read_excel('./data/2019-Estatistika-Taulak-4T-C.xlsx')
df_2020 = pd.read_excel('./data/2020-Estatistika-Taulak-4T-C.xlsx')
df_2021 = pd.read_excel('./data/2021-Estatistika-Taulak-4T-C.xlsx')

df_2013.columns = df_2013.iloc[7]
df_2013 = df_2013.drop(range(8))
df_2013 = df_2013.reset_index(drop=True)
df_2013.columns = df_2013.iloc[0]

df_2014.columns = df_2014.iloc[7]
df_2014 = df_2014.drop(range(8))
df_2014 = df_2014.reset_index(drop=True)
df_2014 = df_2014.drop(df_2014.columns[1], axis=1)
df_2014.columns = df_2014.iloc[0]

df_2015.columns = df_2015.iloc[7]
df_2015 = df_2015.drop(range(8))
df_2015 = df_2015.reset_index(drop=True)
df_2015.columns = df_2015.iloc[0]

df_2016.columns = df_2016.iloc[7]
df_2016 = df_2016.drop(range(8))
df_2016 = df_2016.reset_index(drop=True)
df_2016 .columns = df_2016.iloc[0]

df_2017.columns = df_2017.iloc[7]
df_2017 = df_2017.drop(range(8))
df_2017 = df_2017.reset_index(drop=True)
df_2017.columns = df_2017.iloc[0]

df_2018.columns = df_2018.iloc[7]
df_2018 = df_2018.drop(range(8))
df_2018 = df_2018.reset_index(drop=True)
df_2018.columns = df_2018.iloc[0]

df_2019.columns = df_2019.iloc[6]
df_2019 = df_2019.drop(range(7))
df_2019 = df_2019.reset_index(drop=True)
df_2019.columns = df_2019.iloc[0]

df_2020.columns = df_2020.iloc[6]
df_2020 = df_2020.drop(range(7))
df_2020 = df_2020.reset_index(drop=True)
df_2020.columns = df_2020.iloc[0]

df_2021.columns = df_2021.iloc[6]
df_2021 = df_2021.drop(range(7))
df_2021 = df_2021.reset_index(drop=True)
df_2021.columns = df_2021.iloc[0]

df_2013['año'] = 2013
df_2014['año'] = 2014
df_2015['año'] = 2015
df_2016['año'] = 2016
df_2017['año'] = 2017
df_2018['año'] = 2018
df_2019['año'] = 2019
df_2020['año'] = 2020
df_2021['año'] = 2021

# %%
fuente_10 = 'https://www.eustat.eus/elementos/ele0014600/entradas-y-pernoctaciones-en-apartamentos-turisticos-de-la-ca-de-euskadi-por-mes-y-ano-segun-territorio-historico/tbl0014624_c.html'
df_10 = pd.read_excel('./data/etrtt_01m_20230322-173732.xlsx')
temp_cols = df_10.iloc[1]

# eliminar la fila 1 del DataFrame
df_10 = df_10.drop(1)

# establecer los nombres de las columnas a partir de la variable temporal y sin nombre para el índice
df_10.columns = pd.Index([str(col) for col in temp_cols], name=None)
df_10 = df_10.drop(index=df_10.index[0])
df_10 = df_10.drop(index=df_10.index[14:]).reset_index(drop=True)
df_10 = df_10.transpose()
df_10 = df_10.iloc[:, :-2]

df_10.head()
# Out:
#                        0             1         2          3   \
# nan      Plazas ofertadas           NaN       NaN        NaN
# nan       C.A. de Euskadi  -Araba/Álava  -Bizkaia  -Gipuzkoa
# 2016-01            975659        174932    448487     352240
# 2016-02            942673        169702    429147     343824
# 2016-03           1068127        188718    476109     403300
#
#                                4             5         6          7   \
# nan      Plazas ofertadas por día           NaN       NaN        NaN
# nan               C.A. de Euskadi  -Araba/Álava  -Bizkaia  -Gipuzkoa
# 2016-01                     31473          5643     14467      11363
# 2016-02                     32506          5852     14798      11856
# 2016-03                     34456          6088     15358      13010
#
#                        8             9         10         11
# nan      Personal ocupado           NaN       NaN        NaN
# ...

# %%
fuente_13 = 'https://www.ine.es/jaxiT3/Tabla.htm?t=10916'
df_13 = pd.read_excel('./data/Salario medio anual por grupos de ocupación y periodo..xlsx')
#df_13 = df_13.transpose().reset_index()

df_13.columns = df_13.iloc[0]

df_13 = df_13.drop([0], axis=0)
df_13 = df_13.transpose().reset_index()
df_13.columns = df_13.iloc[0]
df_13 = df_13.drop([0], axis=0)
df_13.columns.values[0] = "año"
# HAY QUE PONER LOS VALORES NEGATIVOS Y LOS QUE NO HAY EN NAN
#df_13.groupby('año').mean()
df_13.head()
# Out:
# 0     año   Total   \
# 1  2020.0  27642.5
# 2  2019.0  26934.4
# 3  2018.0  26738.2
# 4  2017.0  26391.8
# 5  2016.0  25924.4
#
# 0 K Trabajadores cualificados de la construcción, excepto operadores de máquinas  \
# 1                                            21265.6
# 2                                            21070.1
# 3                                            20928.8
# 4                                            20303.3
# 5                                            20191.7
#
# 0 N Conductores y operadores de maquinaria móvil  \
# 1                                        21182.1
# 2                                        20920.0
# 3                                        21487.5
# 4                                        20452.2
# 5                                        20161.1
#
# 0 B Técnicos y profesionales científicos e intelectuales de la salud y la enseñanza  \
# 1                                            37664.4
# ...

# %%
fuente_19 = 'https://ourworldindata.org/travel-carbon-footprint'
df_19 = pd.read_csv('./data/carbon-footprint-travel-mode.csv')
df_19.head()
# Out:
#                      Entity  Code  Year  GHG emissions (gCO2e/km)
# 0          Black cab (taxi)   NaN  2018                  211.7600
# 1                       Bus   NaN  2018                  104.7100
# 2                     Coach   NaN  2018                   27.7900
# 3  Diesel car, 2 passengers   NaN  2018                   85.3050
# 4  Diesel car, 4 passengers   NaN  2018                   42.6525
